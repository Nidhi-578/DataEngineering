# %% [markdown]
# <a href="https://colab.research.google.com/github/Nidhi-578/DataEngineering/blob/main/Function_class3_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Section 1: Lambda Expressions — 20 Questions

# %%
#1. Write a lambda expression to calculate the square of number.
square1=lambda x:x**2
square1(8)
# Out:
# 64

# %%
#2. Write a lambda expression to calculate the cube of number.
cube1=lambda x:x**3
cube1(5)
# Out:
# 125

# %%
#3. Write a lambda expression to add a and b.

add1=lambda a,b:a+b
add1(25,17)
# Out:
# 42

# %%
#4. Write a lambda expression to subtract b from a.
substract1=lambda a,b:a-b
substract1(50,18)
# Out:
# 32

# %%
# 5. Write a lambda expression to multiply a and b.
Multiply=lambda a,b:a*b
Multiply(12,9)
# Out:
# 108

# %%
#6. Write a lambda expression to divide a by b.
devide1=lambda a,b:a/b
devide1(100,4)
# Out:
# 25.0

# %%
#7. Write a lambda expression to return the larger number.
larger=lambda a,b:a if a>b else b
larger(72,91)
# Out:
# 91

# %%
#8. Write a lambda expression to return the smaller number.
smaller=lambda a,b:a if a<b else b
smaller(46,28)
# Out:
# 28

# %%
#9. Write a lambda expression that returns True when the number is even and False otherwise.
number = 34
even = lambda a: a % 2 == 0
print(even(number))
# Out:
# True

# %%
#10. Write a lambda expression that returns True when the number is odd and False otherwise.
number= 27
odd= lambda a: a % 2 == 1
print(odd(number))
# Out:
# True

# %%
#11. Write a lambda expression to calculate the area of a rectangle.
length = 12
width = 8
area = lambda l, w: l * w
print(area(length, width))
# Out:
# 96

# %%
#12. Write a lambda expression to calculate the area of a circle using 3.14.
radius= 7
area_circle=lambda r:3.14*r**2
print(area_circle(radius))
# Out:
# 153.86

# %%
# 13. Write a lambda expression to calculate the perimeter of a rectangle.
length = 15
width = 10
perimeter = lambda l, w: 2 * (l + w)
print(perimeter(length, width))
# Out:
# 50

# %%
#14. Write a lambda expression to convert Celsius into Fahrenheit.
celcius=35
Fahrenheit=lambda c:(9/5)*c+32
print(Fahrenheit(celcius))
# Out:
# 95.0

# %%
#15. Write a lambda expression to convert Fahrenheit into Celsius.
Fahrenheit=95
celcius=lambda f:(5/9)*(f-32)
print(celcius(Fahrenheit))
# Out:
# 35.0

# %%
#16. Write a lambda expression to return the length of the string.
word = "Python"
length = lambda w: len(w)
print(length(word))
# Out:
# 6

# %%
#17. Write a lambda expression to return the first character of the string.
word = "Azure"
first_char = lambda w: w[0]
print(first_char(word))
# Out:
# A

# %%
#18. Write a lambda expression to return the last character of the string.
word = "Databricks"
last_char = lambda w: w[-1]
print(last_char(word))
#
# Out:
# s

# %%
#19. Write a lambda expression to return the absolute value of the number without using abs().
number = -45
absolute_value = lambda n: -n if n < 0 else n
print(absolute_value(number))
# Out:
# 45

# %%
# 20. Write a lambda expression that returns:

#"Distinction" when marks are 75 or above
#"Pass" when marks are 40 to 74
#"Fail" when marks are below 40
marks = 72
result = lambda m: "Distinction" if m >= 75 else ("Pass" if m >= 40 else "Fail")
print(result(marks))
# Out:
# Pass

# %%
# 21. Section 2: map() — 20 Questions

# %%
#1. Using map() and a lambda expression, calculate the square of every number.
numbers = [1, 2, 3, 4, 5, 6]
squared_numbers = list(map(lambda x: x**2, numbers))
print(squared_numbers)
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
#2. Using map() and a lambda expression, calculate the cube of every number.
numbers = [2, 3, 4, 5, 6]
cubed_numbers = list(map(lambda x: x**3, numbers))
print(cubed_numbers)
# Out:
# [8, 27, 64, 125, 216]

# %%
#3. Using map(), add 5 to every number.
numbers = [10, 20, 30, 40, 50]
added_numbers = list(map(lambda x: x + 5, numbers))
print(added_numbers)
# Out:
# [15, 25, 35, 45, 55]

# %%
#4. Using map(), subtract 10 from every number.
numbers = [30, 40, 50, 60, 70]
subtracted_numbers = list(map(lambda x: x - 10, numbers))
print(subtracted_numbers)
# Out:
# [20, 30, 40, 50, 60]

# %%
#5. Using map(), multiply every number by 100.
numbers = [1, 5, 10, 15, 20]
multiplied_numbers = list(map(lambda x: x * 100, numbers))
print(multiplied_numbers)
# Out:
# [100, 500, 1000, 1500, 2000]

# %%
#6. Using map(), convert every name to uppercase.
names = ["ravi", "anil", "meena", "kiran", "sneha"]
uppercased_names = list(map(lambda x: x.upper(), names))
print(uppercased_names)
# Out:
# ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %%
#7. Using map(), convert every name to lowercase.
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
lowercased_names=list(map(lambda x:x.lower(),names))
print(lowercased_names)
# Out:
# ['rahul', 'divya', 'arjun', 'ajay']

# %%
#8. Using map(), convert every name to title case.
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
titlecased_names = list(map(lambda x: x.title(), names))
print(titlecased_names)
# Out:
# ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %%
#9. Using map(), calculate the length of every word.
words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
length=list(map(lambda x:len(x),words))
print(length)
# Out:
# [6, 5, 10, 5, 2]

# %%
# 10. Using map(), extract the first character of every word.
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
first_char=list(map(lambda x:x[0],words))
print(first_char)
# Out:
# ['P', 'A', 'D', 'L', 'S']

# %%
#11. Using map(), extract the last character of every word.
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
last_char=list(map(lambda x:x[-1],words))
print(last_char)
# Out:
# ['n', 'e', 'r', 'x', 'k']

# %%
#12. Using map(), convert every Celsius temperature into Fahrenheit.
temperatures = [0, 10, 20, 30, 40]
fahrenheit=list(map(lambda c:(9/5)*c+32,temperatures))
print(fahrenheit)
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %%
#13. Using map(), calculate 18% GST for every price.
prices = [100, 250, 500, 1000, 2500]
PriceWithGst=list(map(lambda x:x*0.18,prices))
print(PriceWithGst)
# Out:
# [18.0, 45.0, 90.0, 180.0, 450.0]

# %%
#14. Using map(), calculate the final price after adding 18% GST.
prices = [100, 250, 500, 1000, 2500]
final_price=list(map(lambda x:x*1.18,prices))
print(final_price)
# Out:
# [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %%
#15. Using map(), round every number to two decimal places.
decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
rounded_numbers = list(map(lambda x: round(x, 2), decimal_numbers))
print(rounded_numbers)
# Out:
# [12.46, 45.9, 78.12, 100.0]

# %%
#16. Using map(), convert every number into its absolute value.
values = [-10, 20, -35, 40, -55, 60]
absolute_values = list(map(lambda x: abs(x), values))
print(absolute_values)
# Out:
# [10, 20, 35, 40, 55, 60]

# %%
#17. Using map(), convert every integer into a string.
numbers = [10, 20, 30, 40, 50]
string_numbers = list(map(lambda x: str(x), numbers))
print(string_numbers)
# Out:
# ['10', '20', '30', '40', '50']

# %%
#18. Using map(), remove leading and trailing spaces from every name.
names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
final_name=list(map(lambda x:x.strip(),names))
print(final_name)
# Out:
# ['Ravi', 'Anil', 'Meena', 'Kiran']

# %%
#19. Using map(), extract only employee names.
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]

names=list(map(lambda x:x["name"],employees))
print(names)
# Out:
# ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %%
#20. Using map(), create a new list of dictionaries containing:

#Employee name
#Original salary
#Salary after a 10% increment
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
new_dict=list(map(lambda x:{"name":x["name"],"salary":x["salary"],"new_salary":x["salary"]*1.1},employees))
print(new_dict)
# Out:
# [{'name': 'Rahul', 'salary': 45000, 'new_salary': 49500.00000000001}, {'name': 'Anil', 'salary': 65000, 'new_salary': 71500.0}, {'name': 'Sneha', 'salary': 72000, 'new_salary': 79200.0}, {'name': 'Kiran', 'salary': 82000, 'new_salary': 90200.00000000001}]

# %%
#Section 3: filter() — 20 Questions

# %%
#1. Using filter(), extract all even numbers.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
even_numbers=list(filter(lambda x:x%2==0,numbers))
print(even_numbers)
# Out:
# [12, 56, 34, 78, 100]

# %%
#2. Using filter(), extract all odd numbers.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
odd_numbers=list(filter(lambda x:x%2!=0,numbers))
print(odd_numbers)
# Out:
# [45, 67, 89, 23, 91]

# %%
#3. Using filter(), extract all numbers greater than 50.
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
greater_than_50=list(filter(lambda x:x>50,numbers))
print(greater_than_50)
# Out:
# [67, 89, 56, 91, 78, 100]

# %%
#4. Using filter(), extract all numbers less than 100.
numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
less_than_100=list(filter(lambda x:x<100,numbers))
print(less_than_100)
# Out:
# [45, 89, 56, 91, 34]

# %%
#5. Using filter(), extract all positive numbers.
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
positive_numbers=list(filter(lambda x:x>0,numbers))
print(positive_numbers)
# Out:
# [4, 12, 37, 42]

# %%
#6. Using filter(), extract all negative numbers.
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
negative_numbers=list(filter(lambda x:x<0,numbers))
print(negative_numbers)
# Out:
# [-15, -8, -25]

# %%
#7. Using filter(), remove all zero values.
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
non_zero_numbers=list(filter(lambda x:x!=0,numbers))
print(non_zero_numbers)
# Out:
# [-15, -8, 4, 12, -25, 37]

# %%
#8. Using filter(), extract words containing more than five characters.
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
five_char_words=list(filter(lambda x:len(x)>5,words))
print(five_char_words)
# Out:
# ['python']

# %%
#9. Using filter(), map(), and reduce():

#Extract temperatures greater than 30°C.
#Convert the selected values into Fahrenheit.
#Calculate the average Fahrenheit temperature.
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
greater_than_30=list(filter(lambda x:x>30,temperatures))
print(greater_than_30)
fahrenheit=list(map(lambda x:(9/5)*x+32,greater_than_30))
print(fahrenheit)
from functools import reduce
average_fahrenheit=reduce(lambda x,y:x+y,fahrenheit)/len(fahrenheit)
print(average_fahrenheit)
# Out:
# [35, 40, 33, 42]
# [95.0, 104.0, 91.4, 107.60000000000001]
# 99.5

# %%
#10. Using filter(), map(), and reduce():

#Extract prices greater than 1000.
#Apply a 10% discount to every selected price.
#Calculate the total discounted amount.
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
greater_than_1000=list(filter(lambda x:x>1000,prices))
print(greater_than_1000)
after_discount=list(map(lambda x:x*0.1,greater_than_1000))
print(after_discount)
total_discounted_amount=reduce(lambda x,y:x+y,after_discount)
print(total_discounted_amount)
# Out:
# [1200, 2500, 5000, 1500, 7500]
# [120.0, 250.0, 500.0, 150.0, 750.0]
# 1770.0

# %%
#11. Using filter() and map():

#Extract employees earning more than 60000.
#Increase their salary by 10%.
#Return their names and updated salaries.
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000},
    {"id": 105, "name": "Meena", "salary": 55000}
]
high_earners=list(filter(lambda x:x["salary"]>60000,employees))
print(high_earners)
updated_salaries = list(map(lambda x: {"name": x["name"], "salary": round(x["salary"] * 1.1, 2)}, high_earners))
print(updated_salaries)
# Out:
# [{'id': 102, 'name': 'Anil', 'salary': 65000}, {'id': 103, 'name': 'Sneha', 'salary': 72000}, {'id': 104, 'name': 'Kiran', 'salary': 82000}]
# [{'name': 'Anil', 'salary': 71500.0}, {'name': 'Sneha', 'salary': 79200.0}, {'name': 'Kiran', 'salary': 90200.0}]

# %%
#12. Using filter() and reduce():

#Extract employees from the IT department.
#Calculate the total salary of IT employees.
employees = [
    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
]
it_employees=list(filter(lambda x:x["department"]=="IT",employees))
print(it_employees)
from functools import reduce
total_salary=reduce(lambda x,y:x+y["salary"],it_employees,0)
print(total_salary)
# Out:
# [{'id': 101, 'name': 'Rahul', 'department': 'IT', 'salary': 45000}, {'id': 103, 'name': 'Sneha', 'department': 'IT', 'salary': 72000}, {'id': 104, 'name': 'Kiran', 'department': 'IT', 'salary': 82000}]
# 199000

# %%
#13. Using filter(), map(), and reduce():

#Extract active employees.
#Increase every active employee's salary by 15%.
#Calculate the total updated payroll.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
    {"id": 102, "name": "Anil", "salary": 65000, "active": True},
    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
    {"id": 105, "name": "Meena", "salary": 55000, "active": True},
    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
]
active_employees=list(filter(lambda x:x["active"]==True,employees))
print(active_employees)
updated_salaries=list(map(lambda x:{"name":x["name"],"salary":round(x["salary"]*1.15,2)},active_employees))
print(updated_salaries)
total_payroll=reduce(lambda x,y:x+y["salary"],updated_salaries,0)
print(total_payroll)
# Out:
# [{'id': 101, 'name': 'Rahul', 'salary': 45000, 'active': True}, {'id': 102, 'name': 'Anil', 'salary': 65000, 'active': True}, {'id': 104, 'name': 'Kiran', 'salary': 82000, 'active': True}, {'id': 105, 'name': 'Meena', 'salary': 55000, 'active': True}]
# [{'name': 'Rahul', 'salary': 51750.0}, {'name': 'Anil', 'salary': 74750.0}, {'name': 'Kiran', 'salary': 94300.0}, {'name': 'Meena', 'salary': 63250.0}]
# 284050.0

# %%
#14. Using filter() and reduce():

#Extract students who passed.
#Find the topper among the passed students.

# %%
students = [
    {"name": "Ravi", "marks": 92, "passed": True},
    {"name": "Kiran", "marks": 68, "passed": True},
    {"name": "Meena", "marks": 85, "passed": True},
    {"name": "Ajay", "marks": 48, "passed": True},
    {"name": "Sneha", "marks": 35, "passed": False},
    {"name": "Rahul", "marks": 95, "passed": True}
]
passed_students=list(filter(lambda x:x["passed"]==True,students))
print(passed_students)
topper=reduce(lambda x,y:x if x["marks"]>y["marks"] else y,passed_students)
print(topper)
# Out:
# [{'name': 'Ravi', 'marks': 92, 'passed': True}, {'name': 'Kiran', 'marks': 68, 'passed': True}, {'name': 'Meena', 'marks': 85, 'passed': True}, {'name': 'Ajay', 'marks': 48, 'passed': True}, {'name': 'Rahul', 'marks': 95, 'passed': True}]
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %%
#15. Using filter(), map(), and reduce():

#Extract students scoring more than 70.
#Extract only their marks.
#Calculate the average marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]
more_than_70=list(filter(lambda x:x["marks"]>70,students))
print(more_than_70)
marks=list(map(lambda x:x["marks"],more_than_70))
print(marks)
average_marks=reduce(lambda x,y:x+y,marks)/len(marks)
print(average_marks)
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}, {'name': 'Sneha', 'marks': 79}, {'name': 'Rahul', 'marks': 95}]
# [92, 85, 79, 95]
# 87.75

# %%
#16. Using filter(), map(), and reduce():

#Extract products currently in stock.
#Calculate each product's inventory value using price × stock.
#Calculate the total inventory value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]
in_stock=list(filter(lambda x:x["stock"]>0,products))
print(in_stock)
inventory_value=list(map(lambda x:{"name":x["name"],"inventory_value":x["price"]*x["stock"]},in_stock))
print(inventory_value)
total_inventory_value=reduce(lambda x,y:x+y["inventory_value"],inventory_value,0)
print(total_inventory_value)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}, {'name': 'SSD', 'price': 6500, 'stock': 12}]
# [{'name': 'Laptop', 'inventory_value': 275000}, {'name': 'Mouse', 'inventory_value': 15000}, {'name': 'Monitor', 'inventory_value': 144000}, {'name': 'SSD', 'inventory_value': 78000}]
# 512000

# %%
#17. Using filter(), map(), and reduce():

#Extract products belonging to the Electronics category.
#Apply a 20% discount.
#Calculate the total discounted value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]
electronics_products=list(filter(lambda x:x["category"]=="Electronics",products))
print(electronics_products)
discounted_products=list(map(lambda x:{"name":x["name"],"price":x["price"]*0.8},electronics_products))
print(discounted_products)
total_discounted_value=reduce(lambda x,y:x+y["price"],discounted_products,0)
print(total_discounted_value)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'category': 'Electronics'}, {'name': 'Monitor', 'price': 18000, 'category': 'Electronics'}, {'name': 'SSD', 'price': 6500, 'category': 'Electronics'}]
# [{'name': 'Laptop', 'price': 44000.0}, {'name': 'Monitor', 'price': 14400.0}, {'name': 'SSD', 'price': 5200.0}]
# 63600.0

# %%
#18. Using filter() and reduce():

#Extract delivered orders.
#Calculate the total delivered revenue.

# %%
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]
delivered_orders=list(filter(lambda x:x["status"]=="Delivered",orders))
print(delivered_orders)
total_delivered_revenue=reduce(lambda x,y:x+y["amount"],delivered_orders,0)
print(total_delivered_revenue)
# Out:
# [{'order_id': 1001, 'amount': 1200, 'status': 'Delivered'}, {'order_id': 1003, 'amount': 8500, 'status': 'Delivered'}, {'order_id': 1005, 'amount': 7600, 'status': 'Delivered'}]
# 17300

# %%
#19. Using filter(), map(), and reduce():

#Extract transactions whose amount is greater than 5000.
#Add 18% GST to every selected transaction.
#Calculate the grand total after GST.

# %%
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]
greater_than_5000=list(filter(lambda x:x["amount"]>5000,transactions))
print(greater_than_5000)
gst_added=list(map(lambda x:{"id":x["id"],"amount":x["amount"]*1.18},greater_than_5000))
print(gst_added)
grand_total=reduce(lambda x,y:x+y["amount"],gst_added,0)
print(grand_total)
# Out:
# [{'id': 2, 'amount': 5200}, {'id': 3, 'amount': 18000}, {'id': 5, 'amount': 9600}, {'id': 6, 'amount': 7200}]
# [{'id': 2, 'amount': 6136.0}, {'id': 3, 'amount': 21240.0}, {'id': 5, 'amount': 11328.0}, {'id': 6, 'amount': 8496.0}]
# 47200.0

# %%
#20. Using filter(), map(), and reduce():

#Extract active salespeople from the South region.
#Calculate a 5% incentive for each selected salesperson.
#Create a list containing salesperson name, sales amount, and incentive.
#Calculate the total incentive payable.

# %%
sales_records = [
    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
]
south_salespeople=list(filter(lambda x:x["region"]=="South" and x["active"]==True,sales_records))
print(south_salespeople)
incentives=list(map(lambda x:{"salesperson":x["salesperson"],"sales":x["sales"],"incentive":x["sales"]*0.05},south_salespeople))
print(incentives)
total_incentive=reduce(lambda x,y:x+y["incentive"],incentives,0)
print(total_incentive)
# Out:
# [{'salesperson': 'Rahul', 'region': 'South', 'sales': 45000, 'active': True}, {'salesperson': 'Kiran', 'region': 'South', 'sales': 82000, 'active': True}, {'salesperson': 'Arjun', 'region': 'South', 'sales': 98000, 'active': True}]
# [{'salesperson': 'Rahul', 'sales': 45000, 'incentive': 2250.0}, {'salesperson': 'Kiran', 'sales': 82000, 'incentive': 4100.0}, {'salesperson': 'Arjun', 'sales': 98000, 'incentive': 4900.0}]
# 11250.0
